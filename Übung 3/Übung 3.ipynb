# %% [markdown]
# # Übungsblatt 3
#
# Lernziele:
# - Clustering mit K-Means und Gaußscher Mischverteilung
# - Einsatz von SciKit Learn

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Schritt 1: Lesen Sie die Trainings-Daten aus 'data/2d_samples_4cl_train.csv' ein!

# %%
df = pd.read_csv("data/2d_samples_4cl_train.csv")
df.set_index("Label", inplace=True)
df
# Out:
#             x1        x2
# Label
# A      25.5428   8.12002
# A      28.7852  10.51880
# B      31.1303   9.20584
# B      31.1073   9.47408
# B      31.2040   9.33927
# ...        ...       ...
# A      29.6667  11.06620
# A      27.5088  10.48770
# D      26.6341   5.35673
# C      30.6132   4.39621
# A      30.4895  11.91220
#
# [2000 rows x 2 columns]

# %% [markdown]
# Schritt 2: Berechnen Sie für die Muster die 4 Klassenmittelpunkte mit Hilfe des K-Means Algorithmus. Verwenden Sie hierbei das Modul SciKit Learn (sklearn)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4).fit(df)
kmeans.cluster_centers_
# Out:
# array([[27.90871948,  9.79630121],
#        [29.96843937,  4.9697589 ],
#        [31.88774519, 10.51734218],
#        [25.74703851,  5.62192724]])

# %% [markdown]
# Schritt 3: Stellen Sie das Ergebnis des Clusterings in einem Scatterplot dar!

# %%
import matplotlib.pyplot as plt

# %%
predictions = kmeans.predict(df)
plt.scatter(df["x1"], df["x2"], c=predictions)
plt.show()

# %% [markdown]
# Schritt 4: Führen Sie das Clustering mit Gaußscher Mischverteilung durch.

# %%
from sklearn.mixture import GaussianMixture

# %%
gm = GaussianMixture(n_components=4).fit(df)
gm.means_
# Out:
# array([[28.01019212,  9.99776289],
#        [25.98784701,  4.94113429],
#        [31.91070535,  9.92765043],
#        [29.98031496,  4.97456756]])

# %% [markdown]
# Schritt 5: Stellen Sie das Ergebnis des Clusterings in einem Scatterplot dar!

# %%
predictions_gm = gm.predict(df)
plt.scatter(df["x1"], df["x2"], c=predictions_gm)
plt.show()

# %% [markdown]
# Schritt 6: Führen Sie die Schritte 4+5 mehrfach hintereinander auf. Was fällt auf?

# %% [markdown]
# <b>Antwort:</b> Sind immer unterschiedlich, siehe Plots.

# %%
for i in range(10):
    gm = GaussianMixture(n_components=4).fit(df)
    predictions_gm = gm.predict(df)
    plt.scatter(df["x1"], df["x2"], c=predictions_gm)
    plt.show()
