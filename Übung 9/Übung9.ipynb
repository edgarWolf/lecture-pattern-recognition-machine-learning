# %% [markdown]
# # Übungsblatt 9
#
# Lernziele:
# - Datenvorbereitung
# - Umgang mit fehlenden Werten

# %% [markdown]
# Schritt 1: Lesen Sie die Daten aus 'autos/imports-85.csv' ein!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("autos/imports-85.csv")
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# Schritt 2: Verschaffen Sie sich einen Überblick über die numerischen Attribute mit Hilfe der Pandas-Methode *describe()*

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          35.442168    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  201.000000  201.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.273539    0.316717
# ...

# %% [markdown]
# Schritt 3: Geben Sie die Anzahl fehlender Werte pro Attribut aus!

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# Schritt 4: Entfernen Sie die Spalte mit den meisten fehlenden Werten!

# %%
df_removed = df.drop('normalized-losses', axis=1)
df_removed
# Out:
#      symboling         make fuel-type aspiration num-of-doors   body-style  \
# 0            3  alfa-romero       gas        std          two  convertible
# 1            3  alfa-romero       gas        std          two  convertible
# 2            1  alfa-romero       gas        std          two    hatchback
# 3            2         audi       gas        std         four        sedan
# 4            2         audi       gas        std         four        sedan
# ..         ...          ...       ...        ...          ...          ...
# 200         -1        volvo       gas        std         four        sedan
# 201         -1        volvo       gas      turbo         four        sedan
# 202         -1        volvo       gas        std         four        sedan
# 203         -1        volvo    diesel      turbo         four        sedan
# 204         -1        volvo       gas      turbo         four        sedan
#
# ...

# %% [markdown]
# Schritt 5: Plotten Sie die Verteilung der Preise der Fahrzeuge (ohne die fehlenden Werte)!

# %%
prices = df_removed[df_removed["price"].notna()]["price"]
prices
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 201, dtype: float64

# %%
plt.hist(prices)
plt.show()

# %% [markdown]
# Schritt 6: Geben Sie nur die Samples aus, bei denen die Fahrzeugpreise fehlen!

# %%
samples_without_price = df_removed[df_removed["price"].isna()]
samples_without_price
# Out:
#      symboling     make fuel-type aspiration num-of-doors body-style  \
# 9            0     audi       gas      turbo          two  hatchback
# 44           1    isuzu       gas        std          two      sedan
# 45           0    isuzu       gas        std         four      sedan
# 129          1  porsche       gas        std          two  hatchback
#
#     drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# 9            4wd           front        99.5   178.2  ...          131
# 44           fwd           front        94.5   155.9  ...           90
# 45           fwd           front        94.5   155.9  ...           90
# 129          rwd           front        98.4   175.7  ...          203
#
#      fuel-system  bore stroke compression-ratio  horsepower peak-rpm  \
# 9           mpfi  3.13   3.40               7.0       160.0   5500.0
# 44          2bbl  3.03   3.11               9.6        70.0   5400.0
# ...

# %% [markdown]
# Schritt 7: Ersetzen Sie die fehlenden Fahrzeugpreise durch den Median-Wert!

# %%
price_median = df_removed["price"].median()
price_median
# Out:
# 10295.0

# %%
df_removed.loc[df_removed["price"].isna(), ["price"]] = price_median
df_removed
# Out:
#      symboling         make fuel-type aspiration num-of-doors   body-style  \
# 0            3  alfa-romero       gas        std          two  convertible
# 1            3  alfa-romero       gas        std          two  convertible
# 2            1  alfa-romero       gas        std          two    hatchback
# 3            2         audi       gas        std         four        sedan
# 4            2         audi       gas        std         four        sedan
# ..         ...          ...       ...        ...          ...          ...
# 200         -1        volvo       gas        std         four        sedan
# 201         -1        volvo       gas      turbo         four        sedan
# 202         -1        volvo       gas        std         four        sedan
# 203         -1        volvo    diesel      turbo         four        sedan
# 204         -1        volvo       gas      turbo         four        sedan
#
# ...
